# %% [markdown]
# <a href="https://colab.research.google.com/github/MaksimenkoNikolai/my_python/blob/master/football2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/football.csv"

football = pd.read_csv(url)
football.head()
# Out:
#    Unnamed: 0               Name  Age  ... GKKicking GKPositioning  GKReflexes
# 0           0           L. Messi   31  ...        15            14           8
# 1           1  Cristiano Ronaldo   33  ...        15            14          11
# 2           2          Neymar Jr   26  ...        15            15          11
# 3           3             De Gea   27  ...        87            88          94
# 4           4       K. De Bruyne   27  ...         5            10          13
#
# [5 rows x 42 columns]

# %%
small_football = football[football.columns[1:8]].head(25)
small_football
# Out:
#                  Name  Age Nationality  ...      Value    Wage  Position
# 0            L. Messi   31   Argentina  ...  110500000  565000        RF
# 1   Cristiano Ronaldo   33    Portugal  ...   77000000  405000        ST
# 2           Neymar Jr   26      Brazil  ...  118500000  290000        LW
# 3              De Gea   27       Spain  ...   72000000  260000        GK
# 4        K. De Bruyne   27     Belgium  ...  102000000  355000       RCM
# 5           E. Hazard   27     Belgium  ...   93000000  340000        LF
# 6           L. Modrić   32     Croatia  ...   67000000  420000       RCM
# 7           L. Suárez   31     Uruguay  ...   80000000  455000        RS
# 8        Sergio Ramos   32       Spain  ...   51000000  380000       RCB
# 9            J. Oblak   25    Slovenia  ...   68000000   94000        GK
# 10     R. Lewandowski   29      Poland  ...   77000000  205000        ST
# 11           T. Kroos   28     Germany  ...   76500000  355000       LCM
# ...

# %%
s = small_football['Nationality'].value_counts()
s
# Out:
# Spain        4
# Belgium      3
# Germany      3
# Uruguay      3
# Argentina    3
# France       2
# Portugal     1
# England      1
# Croatia      1
# Poland       1
# Slovenia     1
# Brazil       1
# Italy        1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Belgium', 'Germany', 'Uruguay', 'Argentina', 'France',
#        'Portugal', 'England', 'Croatia', 'Poland', 'Slovenia', 'Brazil',
#        'Italy'],
#       dtype='object')

# %% [markdown]
# # **Задания:**

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/football.csv"

football = pd.read_csv(url)
football
# Out:
#        Unnamed: 0                Name  ...  GKPositioning GKReflexes
# 0               0            L. Messi  ...             14          8
# 1               1   Cristiano Ronaldo  ...             14         11
# 2               2           Neymar Jr  ...             15         11
# 3               3              De Gea  ...             88         94
# 4               4        K. De Bruyne  ...             10         13
# ...           ...                 ...  ...            ...        ...
# 12892       13121        J. Lundstram  ...              8          9
# 12893       13122  N. Christoffersson  ...              5         12
# 12894       13123           B. Worman  ...              6         13
# 12895       13124      D. Walker-Rice  ...              8          9
# 12896       13125           G. Nugent  ...             12          9
#
# [12897 rows x 42 columns]

# %%
s = football['Club'].value_counts()
len(s.index)
# Out:
# 650

# %%
s = football['Club'].value_counts()
s.index[len(s.index)-1]
# Out:
# 'Atlético Mineiro'

# %%
s =football['Position'].value_counts(normalize=True)
s.loc[s > 0.1].index
# Out:
# Index(['GK', 'ST', 'CB'], dtype='object')

# %%
s =football['Position'].value_counts(normalize=True)
s.loc[s < 0.01].index
# Out:
# Index(['LS', 'RS', 'RWB', 'LWB', 'CF', 'LF', 'RF', 'LAM', 'RAM'], dtype='object')

# %%
s = football['FKAccuracy'].value_counts(bins=5)
print(str(s.index[0].left)+'-'+str(s.index[0].right))
# Out:
# 21.2-39.4

# %%
s = football['FKAccuracy'].value_counts()
s.index[0]
# Out:
# 32

# %%
s = football[football.Nationality=='Spain']
round(s['Wage'].value_counts(bins=4).values[0]/len(s)*100)
# Out:
# 97.0

# %%
s=football.loc[football['Club']=='Manchester United']
s=s['Nationality']
len(s.unique())
# Out:
# 13

# %%
s=football.loc[football['Club']=='Juventus']
s=s.loc[football['Nationality']=='Brazil']
s=s['Name'].unique()
s[[0,len(s)-1]]
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
s=football.loc[football['Age']>35]['Club'].value_counts()
s.loc[s==s.max()]
# Out:
# Hokkaido Consadole Sapporo    4
# Club Atlético Huracán         4
# Name: Club, dtype: int64

# %%
football.loc[football['Nationality']=='Argentina']['Age'].value_counts(bins=4).values[3]
# Out:
# 49

# %%
s=football.loc[football['Nationality']=='Spain']['Age'].value_counts(normalize=True)
s=s.values[0]*100
round(s,2)
# Out:
# 11.77
